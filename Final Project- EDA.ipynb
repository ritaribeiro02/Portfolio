# %% [markdown]
# Data profiling is the process of analyzing a dataset to understand its structure, quality, and key characteristics before conducting further analysis. It helps data analysts and scientists detect missing values, outliers, duplicate records, inconsistencies, and patterns that could impact data-driven decision-making.
#
# Why is Data Profiling Important?
#
# Ensures Data Quality
#
# Identifies missing, inconsistent, or incorrect data.
#
# Speeds Up Analysis
#
# Quickly summarizes key statistics.
#
# Enhances Decision-Making.
#
# Provides insights for data cleaning, transformation, and validation.
#
# Detects Anomalies
#
# Helps uncover unexpected patterns or errors.
#
# Improves Data Governance
#
# Ensures compliance with standards and regulations.

# %%
# Install packages
! pip install ydata_profiling

# Call libraries
import pandas as pd
from ydata_profiling import ProfileReport
from google.colab import drive
drive.mount('/content/drive')

# Load the transformed dataset
file_path = "/content/df.csv"  # Ensure this file is in your working directory
df = pd.read_csv(file_path)

# Generate the Pandas Profiling Report
profile = ProfileReport(df, title="Final Project data profilling", explorative=True)

# Save the report to an HTML file
profile.to_file("/content/drive/MyDrive/final project.html")

print("Profiling report generated: final project.html")
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.
