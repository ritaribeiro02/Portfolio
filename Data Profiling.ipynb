# %%
# Install packages
! pip install ydata_profiling

# Call libraries
import pandas as pd
from ydata_profiling import ProfileReport
from google.colab import drive
drive.mount('/content/drive')
import os

# Load the transformed dataset
file_path = "/content/olist_products_dataset.csv"  # Ensure this file is in your working directory
df = pd.read_csv(file_path)

# Generate the Pandas Profiling Report
profile = ProfileReport(df, title="Olist Data Profiling Report", explorative=True)

# Define the directory path
output_dir = "/content/drive/MyDrive/m0_testgit/m0_test1/"
# Create the directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Define the full path for the report file
report_file_path = os.path.join(output_dir, "olist_data_report.html")

# Save the report to an HTML file
profile.to_file(report_file_path)

print(f"Profiling report generated: {report_file_path}")
profile
# Out:
# Output hidden; open in https://colab.research.google.com to view.
